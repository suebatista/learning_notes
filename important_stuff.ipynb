# %% [markdown]
# <a href="https://colab.research.google.com/github/suebatista/learning_notes/blob/main/important_stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
#Google drive
from google.colab import drive
drive.mount("/content/drive")
#dataframe principal
df_ajustado= pd.read_csv('/content/drive/My Drive/5. cronicidade/dataframes/df_ajustado.csv')
#Selecionando doença específica
df=df_ajustado[['idPessoa','diabetes_enf','Sexo','Idade']]
# Out:
# Mounted at /content/drive

# %%
#Changing the type of the data -astype()
df['Idade']=df['Idade'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.iloc[:, 0:3] ### Selective index based column ranges slicing
# Out:
#                                    idPessoa  diabetes_enf Sexo
# 0      bdfb3872-457e-4985-ae3a-209fd2ccd81e             1    M
# 1      74ca6173-ec9f-4aac-90df-860bdb0dfa5d             0    F
# 2      845ba847-4782-4b51-887d-852a40b4cdec             0    F
# 3      74e1dfc1-1326-4020-a547-16ff2216da25             0    F
# 4      3bd04832-a9bc-4599-8c7a-11e444469bf3             0    M
# ...                                     ...           ...  ...
# 21810  9bf091af-81b5-46fd-86a9-690a889151bd             0    F
# 21811  3d939f56-3f38-4877-b822-efb3459b6e17             0    F
# 21812  b9e13c05-1100-42af-aa51-1b5255549a5c             0    F
# 21813  eb977569-c016-4900-af9a-fdeb41860ce1             0    F
# 21814  a4f82e04-c4d4-4e02-bcdc-bcaad9707c59             0    F
#
# [21815 rows x 3 columns]

# %%
#float with two decimals places
import pandas as pd 
pd.options.display.float_format = "{:,.2f}".format
x=[0.22222,0.01920202,0.19202]
x= pd.DataFrame(data=x)
x


#OR

df["column"] = df["column"].astype("float").round(2)

# %%
#Replace values 
dfcontas['valorxpago']=dfcontas['valorxpago'].replace(',', '.',regex=True)

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Modelo escolhido para teste
classifier = GradientBoostingClassifier

# Divindindo em training e test set
X=df_final.drop(columns=['target']).copy()
Y=df_final['target'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=42)

# Pipeline SEM oversampling ou undersampling 
pipeline = make_pipeline(classifier(random_state=42))
model = pipeline.fit(X_train, y_train)
prediction = model.predict(X_test)

# Pipeline COM SMOTE imblearn
smote_pipeline = make_pipeline_imb(SMOTE(random_state=4), classifier(random_state=42))
smote_model = smote_pipeline.fit(X_train, y_train)
smote_prediction = smote_model.predict(X_test)

#Pipeline COM NearMiss undersampling
nearmiss_pipeline = make_pipeline_imb(NearMiss(random_state=42), classifier(random_state=42))
nearmiss_model = nearmiss_pipeline.fit(X_train, y_train)
nearmiss_prediction = nearmiss_model.predict(X_test)

# %%
#filtro baseado em condições - https://kanoki.org/2020/01/21/pandas-dataframe-filter-with-multiple-conditions/
dataframe.loc[(dataframe[exame]>=periodo_meses) | (dataframe[exame].isnull())]

# %%
#deletar columnas pós join
df_diabetes=glicada.set_index('idPessoa').join(glicose.set_index('idPessoa'),lsuffix='_left').filter(regex="^(?!.*_left)")\
.reset_index()

# %%
from pylab import plot, show, legend, title, xlabel, ylabel
meses = ['Jan', 'Fev', 'Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
Tmax = [38,39,32,29,26,22,19,15,20,22,25,27]
Tmin = [23,23,22,21,19,16,12,10,16,21,22,22]
plot(meses,Tmax,meses,Tmin)
title('Temperaturas Máximas e Mínimas do Ano')
xlabel('Mês')
ylabel('Temp/°C')
legend(['Tmax','Tmin'])
show()

# %%
from pylab import plot, show, legend, title, xlabel, ylabel
meses = ['baseline', 'modelo sem exames', 'modelo com exames']
Diabetes = [0.09,0.17,0.29]
Dislipidemia = [0.05,0.08,0.24]
Cardiopatias = [0.10,0.16,0.14]
plot(meses,Diabetes, Dislipidemia, marker=".")
title('Precisão dos modelos de crônicos')
xlabel('modelos')
ylabel('precision')
legend(['Diabetes','Dislipidemia','Cardiopatias'])
show()

# %%
from pylab import plot, show, legend, title, xlabel, ylabel
meses = ['baseline', 'modelo sem exames', 'modelo com exames']
Diabetes = [0.09,0.17,0.29]
Dislipidemia = [0.05,0.08,0.24]

plot(meses,Diabetes, Dislipidemia,Cardiopatias, marker=".")
title('Precisão dos modelos de crônicos')
xlabel('modelos')
ylabel('precision')
legend(['Diabetes','Dislipidemia','Cardiopatias'])
show()

# %%
import matplotlib as plt 
grupos = ['Baseline', 'XGBoost sem exames', 'XGBoost com exames']
valores = [0.20, 0.24, 0.49]
plt.figure(figsize=(8,8))
plt.bar(grupos, valores)
plt.ylabel('precisão')
plt.xlabel('modelos')
plt.title('Precisão dos modelos de Diabetes')
plt.show()
from matplotlib.pyplot import figure

plt.legend(fontsize = 14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-640c734c0ddf> in <module>()
#       1 grupos = ['Baseline', 'XGBoost sem exames', 'XGBoost com exames']
#       2 valores = [0.20, 0.24, 0.49]
# ----> 3 plt.figure(figsize=(8,8))
#       4 plt.bar(grupos, valores)
#       5 plt.ylabel('precisão')
#
# NameError: name 'plt' is not defined

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df=pd.DataFrame({'x_values': ['baseline','sem exames','com exames'],'Dislipidemia': [0.05,0.08,0.24], 'Cardiopatias': [0.10,0.16,0.14], 'Diabetes': [0.09,0.17,0.29] })
 
# multiple line plots
plt.plot('x_values','Dislipidemia', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.plot('Cardiopatias', data=df, marker='o', markerfacecolor='violet', markersize=12, color='deeppink', linewidth=2)
plt.plot('Diabetes', data=df, marker='o', markerfacecolor='green', markersize=12, color='lime', linewidth=2)

title('Precisão dos modelos de crônicos')
xlabel('modelos')
ylabel('precision')
# show legend
plt.legend()

# show graph
plt.show()

# %%
from google.colab import files
df.to_csv('filename.csv') 
files.download('filename.csv')

# %%
import pandas as pd 
import time
print('Hi,Jesse')
time.sleep(2)
print('Most known as gostoso')
time.sleep(2)
print('Just wanted to say youre amazing <3')
time.sleep(2)
print('and I like your dick :p')
# Out:
# Hi,Jesse
# Most known as gostoso
# Just wanted to say youre amazing <3
# and I like your dick :p

# %% [markdown]
# confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
y_true = [0,1,1,0,0,0,1]
y_pred = [0,1,1,0,0,0,1]
confusion_matrix=confusion_matrix(y_true, y_pred)
sns.heatmap(confusion_matrix, annot=True,cmap='Purples', fmt='g',xticklabels=(['Cow','Racoon']),yticklabels=(['Cow','Racoon']))
plt.title('Is this a racoon or a cow?')
plt.xlabel("Predicted")
plt.ylabel("True labels")
plt.figure(figsize=(40,30))

# %% [markdown]
# getting the name of dataframe

# %%
import pandas as pd 
df=pd.DataFrame(data=(1,2,3))
df.name = 'Ones'

print(df.name)
# Out:
# Ones
